# %%
import pandas as pd   
import matplotlib.pyplot as plt  
import seaborn as sns

#Dataset1
d1con=pd.read_csv('dataset1_concentration.csv')
d1COV=pd.read_csv('dataset1_covariates.csv')

#Dataset2
d2con=pd.read_csv('dataset2_concentration.csv')
d2COV=pd.read_csv('dataset2_covariates.csv')

# %%
#DATASET2
#managing the nulls..
miss=d2COV.isnull().sum()
miss.sort_values(ascending=False) #print the sorted list of null values

d2COV.dropna(axis=1).head(5) #AXIS1 Cancels Columns with null values

miss1=d2COV.isnull().sum()
miss1.sort_values(ascending=False)

d2COV.dropna(axis=1).head(5)
# Out:
#    age     sex                race      weight  SNP  hemoglobine  albumine  \
# 0   44    male            Hispanic   89.790817    2    14.889593  3.635106
# 1   38  female            Hispanic   86.077423    2    11.900736  3.440452
# 2   50  female  Caucasian-American   73.073636    3     8.482810  3.658107
# 3   59  female            Hispanic   68.661344    1    14.392393  4.460950
# 4   55  female               Other  110.319654    2    13.180028  3.881203
#
#    last_dose_time  mg_twice_daily_dose  blood_conc          CL            V  \
# 0              52             2.653473   11.567673  241.395784  4005.087001
# 1              52             3.910673    8.863132  231.012497  2616.521283
# 2              52             5.113588    8.108588  121.580674  1333.500735
# 3              52             1.839109    8.195795  268.821107  2682.573872
# 4              52             4.588936    7.112448  393.371628  3385.273705
#
#          ke
# 0  0.060272
# 1  0.088290
# 2  0.091174
# ...

# %%
d2COV.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'SNP'}>],
#        [<Axes: title={'center': 'hemoglobine'}>,
#         <Axes: title={'center': 'albumine'}>,
#         <Axes: title={'center': 'last_dose_time'}>],
#        [<Axes: title={'center': 'mg_twice_daily_dose'}>,
#         <Axes: title={'center': 'blood_conc'}>,
#         <Axes: title={'center': 'CL'}>],
#        [<Axes: title={'center': 'V'}>, <Axes: title={'center': 'ke'}>,
#         <Axes: >]], dtype=object)

# %%
d2COV.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'SNP'}>],
#        [<Axes: title={'center': 'hemoglobine'}>,
#         <Axes: title={'center': 'albumine'}>,
#         <Axes: title={'center': 'last_dose_time'}>],
#        [<Axes: title={'center': 'mg_twice_daily_dose'}>,
#         <Axes: title={'center': 'blood_conc'}>,
#         <Axes: title={'center': 'CL'}>],
#        [<Axes: title={'center': 'V'}>, <Axes: title={'center': 'ke'}>,
#         <Axes: >]], dtype=object)

# %%
age=sns.barplot(x='age',y='blood_conc',data=d2COV)
